# %% [markdown]
# ![image](https://raw.githubusercontent.com/IBM/watson-machine-learning-samples/master/cloud/notebooks/headers/watsonx-Prompt_Lab-Notebook.png)
# # Use Watsonx to analyze car rental customer satisfaction and offer recommendation.

# %% [markdown]
# **Note:** Please note that for the watsonx challenge, please run these notebooks in IBM Cloud and not on on your laptop/desktop.

# %% [markdown]
# This notebook contains the steps and code to demonstrate support of text sentiment analysis in Watsonx. It introduces commands for data retrieval, model testing and scoring.
#
# Some familiarity with Python is helpful. This notebook uses Python 3.10.

# %% [markdown]
# <a id="setup"></a>
# ## Set up the environment

# %% [markdown]
# ### Install and import the dependecies

# %%
# !pip install datasets | tail -n 1
# !pip install scikit-learn | tail -n 1
# !pip install ibm-watson-machine-learning==1.0.312 | tail -n 1
# Out:
# Successfully installed datasets-2.15.0 dill-0.3.7 fsspec-2023.10.0 huggingface-hub-0.19.4 multiprocess-0.70.15 pyarrow-hotfix-0.6 xxhash-3.4.1
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from scikit-learn) (2.2.0)
# Successfully installed ibm-watson-machine-learning-1.0.312

# %% [markdown]
# **Note:** Please restart the notebook kernel to pick up proper version of packages installed above.

# %%
import os, getpass
from pandas import read_csv, concat

# %% [markdown]
# ### Watsonx API connection
# This cell defines the credentials required to work with watsonx API for Foundation
# Model inferencing.
#
# **Action:** Provide the IBM Cloud user API key. Instructions have been provided to generate IBM Cloud API key. For details, see
# [documentation](https://cloud.ibm.com/docs/account?topic=account-userapikey&interface=ui).

# %%
from ibm_cloud_sdk_core import IAMTokenManager
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator, BearerTokenAuthenticator
import os, getpass

access_token = IAMTokenManager(
#     apikey = getpass.getpass("Please enter your api key (hit enter): "),
    apikey = "EQKPblVNI4xAQsorly666ngHKKd4oGxECdByjRuSD16b",
    url = "https://iam.cloud.ibm.com/identity/token"
).get_token()

# %% [markdown]
# ### Defining the project id
# The API requires project id that provides the context for the call. We will obtain the id from the project in which this notebook runs. When you run notebook on IBM Cloud, project in which it runs is saved as environment variable PROJECT_ID.
#
# **Hint**: You can find the `project_id` as follows. Open the prompt lab in watsonx.ai. At the very top of the UI, there will be `Projects / <project name> /`. Click on the `<project name>` link. Then get the `project_id` from Project's Manage tab (Project -> Manage -> General -> Details).

# %%
try:
    project_id = os.environ["PROJECT_ID"]
except KeyError:
    project_id = input("Please enter your project_id (hit enter): ")

# %% [markdown]
# <a id="data"></a>
# ## Train/test data loading

# %% [markdown]
# Load train and test datasets. At first, training dataset (`train_data`) should be used to work with the models to prepare and tune prompt. Then, test dataset (`test_data`) should be used to calculate the metrics score for selected model, defined prompts and parameters.

# %%
filename_test = 'https://watsonx-gsi-challenge.s3.jp-tok.cloud-object-storage.appdomain.cloud/track1/test.csv'
filename_train = 'https://watsonx-gsi-challenge.s3.jp-tok.cloud-object-storage.appdomain.cloud/track1/train.csv'

test_data = read_csv(filename_test)
train_data = read_csv(filename_train)
all_data = concat([train_data, test_data])
print(all_data.shape[0])
use_data = test_data
# Out:
# 150

# %%
train_data.head()
# Out:
#      ID  Gender Status  Children    Age Customer_Status Car_Owner  \
# 0  2944  Female      M         2  41.92          Active        No
# 1  1119  Female      M         2  33.60          Active       Yes
# 2     0    Male      M         0  51.00        Inactive       Yes
# 3  1085  Female      S         2  42.00        Inactive        No
# 4     0  Female      M         2  44.10          Active        No
#
#                                     Customer_Service  Satisfaction  \
# 0         Customer service was friendly and helpful.             1
# 1  Customer service was good at MSP airport and t...             1
# 2  I do not  understand why I have to pay additio...             0
# 3  Based on the customer service personnel I enco...             0
# 4  Provide more convenient car pickup from the ai...             0
#
#                   Business_Area                     Action
# 0            Service: Knowledge                        NaN
# 1            Service: Knowledge                        NaN
# 2  Product: Pricing and Billing           Premium features
# 3             Service: Attitude  On-demand pickup location
# 4     Service: Orders/Contracts  On-demand pickup location

# %%
test_data.head()
# Out:
#      ID  Gender Status  Children    Age Customer_Status Car_Owner  \
# 0  2771  Female      M         2  49.99        Inactive        No
# 1  1133    Male      S         1  56.05        Inactive        No
# 2   900  Female      M         1  64.64          Active        No
# 3  3795    Male      M         0  46.51        Inactive        No
# 4  3541    Male      S         1  17.01        Inactive       Yes
#
#                                     Customer_Service  Satisfaction  \
# 0  last time I rented a car was at Manchester, NH...             0
# 1                           Please lower the prices.             0
# 2        Excellent response dealing with child seat.             1
# 3  all went quite smoothly... it was Enterprise, ...             1
# 4                                  Slow, long lineup             0
#
#                   Business_Area                     Action
# 0          Product: Functioning  On-demand pickup location
# 1  Product: Pricing and Billing               Free Upgrade
# 2        Service: Accessibility                        NaN
# 3        Service: Accessibility                        NaN
# 4          Product: Functioning  On-demand pickup location

# %% [markdown]
# <a id="models"></a>
# ## Foundation Models on Watsonx

# %% [markdown]
# Below code invokes Watson Machine Learning API to invoke Watsonx.ai LLMs

# %%
import requests

class Prompt:
    def __init__(self, access_token, project_id):
        self.access_token = access_token
        self.project_id = project_id

    def generate(self, input, model_id, parameters):
        wml_url = "https://us-south.ml.cloud.ibm.com/ml/v1-beta/generation/text?version=2023-05-28"
        Headers = {
            "Authorization": "Bearer " + self.access_token,
            "Content-Type": "application/json",
            "Accept": "application/json"
        }
        data = {
            "model_id": model_id,
            "input": input,
            "parameters": parameters,
            "project_id": self.project_id
        }
        response = requests.post(wml_url, json=data, headers=Headers)
        if response.status_code == 200:
            return response.json()["results"][0]["generated_text"].strip()
        else:
            return response.text

# %% [markdown]
# <a id="predict"></a>
# ## Evaluate the model, prompt and parameters

# %% [markdown]
# ### **1. Customer satisfaction**

# %% [markdown]
# Define instructions for the model to recognize if customer was satisfied or unsatisfied.
#
# **Note:** Please **start with using [watsonx.ai Prompt Lab](https://dataplatform.cloud.ibm.com/wx/home?context=wx)** to find better prompts that provides you the best result on a small subset training records (under `train_data` variable). Make sure to not run an inference of all of `train_data`, as it'll take a long time to get the results. To get a sample from `train_data`, you can use e.g.`train_data.head(n=10)` to get first 10 records, or `train_data.sample(n=10)` to get random 10 records. Only once you have identified the best performing prompt, update this notebook to use the prompt and compute the metrics on the test data.
#
# **Action:** Please edit the below cell and add your own prompt here. In the below prompt, we have the instruction (first sentence) and one example included in the prompt.  If you want to change the prompt or add your own examples or more examples, please change the below prompt accordingly.

# %%
satisfaction_instruction = """
Classify the sentiment of the comment as either "no" or "yes"

comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be\n
satisfaction: no

comment: Person very friendly but only person working counter
satisfaction: yes

comment: it was fine, I had no problem at all.
satisfaction: yes

comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
satisfaction: yes
"""

# %% [markdown]
# ### Defining the model parameters
# We need to provide a set of model parameters that will influence the result. We will use IBM's Granite model.

# %%
parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 10,
    "min_new_tokens": 0,
    "repetition_penalty": 1
}

model_id = "ibm/granite-13b-instruct-v1"

# %% [markdown]
# Analyze the customer satisfaction for inputs from the test set.
#
# **Note:** Execution of this cell could take several minutes.

# %%
results = []
prompt = Prompt(access_token, project_id)
comments = list(use_data.Customer_Service)
satisfaction = ['no' if x == '0' else 'yes' for x in list(use_data.Satisfaction.astype(str))]

# print(comments)
for idx, input_text, in enumerate(comments):
    prompt_template = satisfaction_instruction + "\ncomment: " + input_text + "\n\nsatisfaction:"
    print(prompt_template)
#     prompt_form = " ".join([satisfaction_instruction, input_text])
    generated = prompt.generate(prompt_template, model_id, parameters)
#     results.append(prompt.generate(" ".join([satisfaction_instruction, input_text, "\n"]), model_id, parameters))
#     print("\n\nPROMPT:", prompt_form,"\nRESULT:", generated, "\nExpected:", satisfaction[idx])
    results.append(generated)
    if generated != satisfaction[idx]:
        print("\nRESULT:", generated, "\nExpected:", satisfaction[idx])
# Out:
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Please lower the prices.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Excellent response dealing with child seat.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: all went quite smoothly... it was Enterprise, so they even picked me up to get the car... it was very convenient.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Slow, long lineup
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
#
# satisfaction:
#
# RESULT: yes
# Expected: no
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: They were actually very nice. It was in Rome and there was a language barrier, but we overcame it.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: They should upgrade me every time.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: They provided the best service thus far. They are very friendly and helpful. I have rented from other companies before both cheaper and more expensive.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: I recently rented a car and they were outstanding.  The customer service rep was very helpful and courteous.  They even let me extend my rental by a couple of hours for no charge at all. I was very pleased with my experience and I would go back.
#
# satisfaction:
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: It was okay, we got the car quickly, which is the most important thing
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: they were fine.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Most windows were closed.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: The woman at the counter was friendly and tried to accommodate me as best she could. The counter was close to the terminal and the whole thing was quick and expedient.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Person very friendly but only person working counter
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: It was fine
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: car cost more because I didn't pay when I reserved it
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Please stop increasing the prices.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Wonderful experience - the rental and whole process was seamless
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: They offered detailed directions.
#
# satisfaction:
# RESULT: no
# Expected: yes
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: fast service
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: They had problem to find reservation number, so whole process took too long time.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: it was a great experience
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Last time I rented a car was when I went skiing with my whole family.  We got a Chevy Blazer.  We didn't think it was as large as a Ford Explorer, so we asked to switch.  The agent was very nice and gave us the Ford Explorer.
#
# satisfaction:
#
# Classify the sentiment of the comment as either "no" or "yes"
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
#
# satisfaction: no
#
# comment: Person very friendly but only person working counter
# satisfaction: yes
#
# comment: it was fine, I had no problem at all.
# satisfaction: yes
#
# comment: My experience was positive .The thing I didnt like was returning the car with full tank.  It was time consuming, but I didn't want to pay fill-up charge to the rental company.
# satisfaction: yes
#
# comment: Everything went fine.  Folks were friendly and informed.
#
# satisfaction:

# %% [markdown]
# ### Calculate the F1 micro score

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
import numpy as np

# print(satisfaction,"\n", results)
print(confusion_matrix(satisfaction, results))
print(classification_report(satisfaction,results, digits=3, zero_division=1, labels=['yes','no']))
print('f1_micro_score', f1_score(satisfaction, results, average='micro', zero_division=1))
# Out:
# [[18  0]
#  [ 3 29]]
#               precision    recall  f1-score   support
#
#          yes      1.000     0.906     0.951        32
#           no      0.857     1.000     0.923        18
#
#     accuracy                          0.940        50
#    macro avg      0.929     0.953     0.937        50
# weighted avg      0.949     0.940     0.941        50
#
# f1_micro_score 0.94

# %% [markdown]
# ### **2. Offer Recommendation**

# %% [markdown]
# Define instructions for the model to recommend best offer to an unsatisfied customer.
#
# **Note:** Please **start with using [watsonx.ai Prompt Lab](https://dataplatform.cloud.ibm.com/wx/home?context=wx)** to find better prompts that provides you the best result on a small subset training records (under `train_data` variable). Make sure to not run an inference of all of `train_data`, as it'll take a long time to get the results. To get a sample from `train_data`, you can use e.g.`train_data.head(n=10)` to get first 10 records, or `train_data.sample(n=10)` to get random 10 records. Only once you have identified the best performing prompt, update this notebook to use the prompt and compute the metrics on the test data.
#
# **Action:** Please edit the below cell and add your own prompt here. In the below prompt, we have the instruction (first sentence) and one example included in the prompt.  If you want to change the prompt or add your own examples or more examples, please change the below prompt accordingly.

# %%
on_demand = test_data.loc[test_data['Action']=='On-demand pickup location']
sample_on_demand = on_demand.head(n=1)
# print(list(sample_on_demand.Customer_Service))
# print(test_data['Action'])

filtered_df = test_data[test_data['Action'].notna()].drop_duplicates(subset=['Action'])
comment_index = filtered_df.columns.get_loc('Customer_Service')
action_list = list(filtered_df.Action)
comment_list = list(filtered_df.Customer_Service)
# get Customer_Service and Action as a list

offer_recommendation_instruction = "Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'."
for idx, value in enumerate(action_list):
    offer_recommendation_instruction += f"\n\ncomment: {comment_list[idx]}\noffer recommended: {value}"

print(offer_recommendation_instruction)

# offer_recommendation_instruction = """
#    Generate next best offer to unsatisfied customer. Choose offer recommendation from the following list: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.\n

#    comment: The company was overwhelmed by the number of customers verse the number of available agents and they were not articulating their situation to the customers well enough. I think we waited for almost 3 hours just to get a rental car. It was ridiculous.\n
#    offer recommended: 'On-demand pickup location'\n\n
# """
# Out:
# Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features

# %% [markdown]
# ### Defining the model parameters
# We need to provide a set of model parameters that will influence the result. We will use IBM's Granite model.

# %%
parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 30,
    "min_new_tokens": 1,
    "repetition_penalty": 1
}

model_id = "ibm/granite-13b-instruct-v1"

# %% [markdown]
# Filter test data for unsatisfied customer

# %%
unsatisfied_test_data = all_data.loc[all_data['Satisfaction'] == 0]
unsatisfied_test_data.head(n=30)
# Out:
#       ID  Gender Status  Children    Age Customer_Status Car_Owner  \
# 2      0    Male      M         0  51.00        Inactive       Yes
# 3   1085  Female      S         2  42.00        Inactive        No
# 4      0  Female      M         2  44.10          Active        No
# 6      0  Female      M         2  44.03          Active        No
# 8      0    Male      S         2  20.40        Inactive        No
# 9      0  Female      S         2  40.50        Inactive        No
# 16  2501  Female      M         1  63.93        Inactive        No
# 18  1190  Female      M         1  52.15        Inactive        No
# 19  2312    Male      S         2  53.28        Inactive        No
# 21  1360  Female      S         0  48.53          Active       Yes
# 23  1897    Male      M         1  46.83        Inactive       Yes
# 27   191    Male      M         0  45.51        Inactive       Yes
# 30   398  Female      S         1  57.55        Inactive        No
# 31   247    Male      M         0  44.00        Inactive        No
# 33  1171    Male      S         0  38.73          Active        No
# 38     0    Male      D         1  33.00          Active        No
# 42     0  Female      M         2  43.00        Inactive       Yes
# 46  3699    Male      M         2  61.71        Inactive       Yes
# 49  1760    Male      M         0  42.17        Inactive        No
# 50  1229  Female      M         0  12.34        Inactive        No
# 53  3716    Male      M         2  61.71        Inactive       Yes
# 57     0  Female      M         0  14.23        Inactive        No
# 59  3411    Male      M         1  58.71        Inactive       Yes
# 64  1307  Female      M         0  55.00        Inactive        No
# 65     0  Female      M         0  16.10        Inactive        No
# 69  3806    Male      S         1  14.64          Active       Yes
# 72  1309  Female      M         0  55.97          Active        No
# 75  2341    Male      M         2  18.77          Active        No
# 76   772  Female      M         2  39.75          Active       Yes
# 80  2558    Male      S         0  55.11        Inactive        No
#
#                                      Customer_Service  Satisfaction  \
# 2   I do not  understand why I have to pay additio...             0
# 3   Based on the customer service personnel I enco...             0
# 4   Provide more convenient car pickup from the ai...             0
# 6                                  VERY slow service!             0
# 8                  They could really try work harder.             0
# 9   I would like the personnel to pretend they car...             0
# 16  The customer service agent was helpful, but I ...             0
# 18  I had to wait in line for a long time to get a...             0
# 19  It was absolutely ATROCIOUS! My wife and I wer...             0
# 21             they should not try so hard to up sell             0
# 23            long lines waiting for the rental pick.             0
# 27          what customer service? It was a nightmare             0
# 30   "sorely lacking"  helpdesk was not much helpfull             0
# 31  delayed shuttle, almost missed flight, bad cus...             0
# 33  I would like the reps be knowledgeable about t...             0
# 38  Did not have some problems. My car was not rea...             0
# 42  Initially the representative handled the situa...             0
# 46  It would be nice if they included maps to the ...             0
# 49  States have different rules and regulations pe...             0
# 50    price too high and location off premise too far             0
# 53  The company was overwhelmed by the number of c...             0
# 57         Even economy class cars are too expensive.             0
# 59  customer service was great until we returned t...             0
# 64  I have had a few recent rentals that have take...             0
# 65  price TOO HIGH and off premise location is NOT...             0
# 69   Having knowledgeable personnel is very important             0
# 72  friendly, but could not making any decisions o...             0
# 75  it seems that they never have the class of car...             0
# 76   They were too pushy in trying to sell insurance.             0
# 80  Customer Service at Alamo was RUDE. We waited ...             0
#
#                          Business_Area                     Action
# 2         Product: Pricing and Billing           Premium features
# 3                    Service: Attitude  On-demand pickup location
# 4            Service: Orders/Contracts  On-demand pickup location
# 6               Service: Accessibility               Free Upgrade
# 8                    Service: Attitude               Free Upgrade
# 9                    Service: Attitude  On-demand pickup location
# 16                Product: Functioning  On-demand pickup location
# 18                Product: Functioning                    Voucher
# 19                Product: Functioning                    Voucher
# 21                   Service: Attitude               Free Upgrade
# 23                Product: Functioning  On-demand pickup location
# 27                  Service: Knowledge                    Voucher
# 30                  Service: Knowledge                    Voucher
# 31                Product: Functioning               Free Upgrade
# 33                Product: Functioning           Premium features
# 38              Service: Accessibility               Free Upgrade
# 42  Product: Availability/Variety/Size               Free Upgrade
# 46                Product: Information           Premium features
# 49                  Service: Knowledge           Premium features
# 50        Product: Pricing and Billing  On-demand pickup location
# 53           Service: Orders/Contracts  On-demand pickup location
# 57        Product: Pricing and Billing  On-demand pickup location
# 59                  Service: Knowledge           Premium features
# 64  Product: Availability/Variety/Size                    Voucher
# 65        Product: Pricing and Billing  On-demand pickup location
# 69                  Service: Knowledge                    Voucher
# 72                  Service: Knowledge           Premium features
# 75                Product: Functioning               Free Upgrade
# 76                Product: Functioning               Free Upgrade
# 80                Product: Functioning               Free Upgrade

# %% [markdown]
# Analyze the recommended actions for inputs from the test set.
#
# **Note:** Execution of this cell could take several minutes.

# %%
results = []
prompt = Prompt(access_token, project_id)
comments = list(unsatisfied_test_data.Customer_Service)
offer_recommended = list(unsatisfied_test_data.Action.astype(str))

for idx,input_text in enumerate(comments):
#     prompt_template = " ".join([offer_recommendation_instruction, input_text])
    prompt_template = offer_recommendation_instruction + "\n\ncomment: " + input_text + "\noffer recommended:"
    gen = prompt.generate(prompt_template, model_id, parameters)
    print("\n\n", prompt_template,"\nResult:", gen, "\nExpected:", offer_recommended[idx])
    results.append(gen)
    
# print(comments)
# print(offer_recommended)
# Out:
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I do not  understand why I have to pay additional fee if vehicle is returned without a full tank.
# offer recommended:
# Result: Voucher
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Based on the customer service personnel I encountered most recently, I would say it is vastly preferable for the personnel to be able to at least pretend to care whether the customer ever actually receives a car rental that was reserved months in advance.
# offer recommended:
# Result: Voucher
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Provide more convenient car pickup from the airport parking.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: VERY slow service!
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: They could really try work harder.
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I would like the personnel to pretend they care about customer, at least.
# offer recommended:
# Result: Voucher
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: The customer service agent was helpful, but I find that providing all of the information to the agent takes too long.  It would be nice if I could provide all of the information to the agent prior to coming the rental place.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I had to wait in line for a long time to get and return the vehicle.  Also, the car was not clean.
# offer recommended:
# Result: On-demand pickup location
# Expected: Voucher
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: It was absolutely ATROCIOUS! My wife and I were in a foreign country  when we realized that our car had an expired license plate and expired proof of insurance!
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: they should not try so hard to up sell
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: long lines waiting for the rental pick.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: what customer service? It was a nightmare
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: "sorely lacking"  helpdesk was not much helpfull
# offer recommended:
# Result: Free Upgrade
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: delayed shuttle, almost missed flight, bad customer service
# offer recommended:
# Result: On-demand pickup location
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I would like the reps be knowledgeable about the immediate area around the rental agency and or have maps for the area available free of charge.
# offer recommended:
# Result: On-demand pickup location
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Did not have some problems. My car was not ready on time.
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Initially the representative handled the situation badly.  No car was available, even next day.  Then the rep helped to find us a car in another agency.
# offer recommended:
# Result: On-demand pickup location
# Expected: Free Upgrade
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: It would be nice if they included maps to the airport drop off with the car, last time we got lost returning the car and almost missed the flight.  There was nothing on the exit that indicated rental returns.  Actually the one I really liked, was when we
# offer recommended:
# Result: On-demand pickup location
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: States have different rules and regulations pertaining to speed, radar detectors, even when light should be on.  Customer services reps should have a handout or be knowledgeable of a particular state's laws.
# offer recommended:
# Result: Voucher
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: price too high and location off premise too far
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: The company was overwhelmed by the number of customers verse the number of available agents and they were not articulating their situation to the customers well enough. I think we waited for almost 3 hours just to get a rental car. It was ridiculous.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Even economy class cars are too expensive.
# offer recommended:
# Result: Free Upgrade
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: customer service was great until we returned the car.  I experienced an issue with damage to the car, and felt that things were left unanswered and still waiting for a response from them.
# offer recommended:
# Result: Voucher
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I have had a few recent rentals that have taken a very very long time, with no offer of apology.  In the most recent case, the agent subsequently offered me a car type on an upgrade coupon and then told me it was no longer available because it had just be
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: price TOO HIGH and off premise location is NOT convenient.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Having knowledgeable personnel is very important
# offer recommended:
# Result: Free Upgrade
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: friendly, but could not making any decisions on own
# offer recommended:
# Result: Free Upgrade
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: it seems that they never have the class of car that I ordered.  also, the last time I got there earlier than I thought and they wouldn't let me have the car until the time that I had requested it because their computer wouldn't allow it.
# offer recommended:
# Result: On-demand pickup location
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: They were too pushy in trying to sell insurance.
# offer recommended:
# Result: Voucher
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Customer Service at Alamo was RUDE. We waited in line for over an hour to get our car. Car was bad. Had to change it few days later. Another family traveling with us was upgraded to a larger car as they were out of the type of car booked.
# offer recommended:
# Result: Voucher
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: They were idiots.  The car had problems and they were unable to fix them or provide a replacement without a lot of hassle.
# offer recommended:
# Result: Voucher
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I had to pay more because of some hidden fees. It disappointed me.
# offer recommended:
# Result: Voucher
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: they could not provide driving directions
# offer recommended:
# Result: On-demand pickup location
# Expected: Premium features
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I thought that they were very short and not very friendly. I felt like they hated their job and could care less about the customer.
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: The car should have been brought to us instead of us trying to find it in the lot.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: They did not have the car I wanted.  upgraded me to a car I did not like and did not want.
# offer recommended:
# Result: Voucher
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Had problems with windshield wipers that affected usability.  Problem was not solved.  Customer service was NOT helpful. Because of franchising, I was not able to get help from an office other than the one I rented from.  I had driven 60 miles from that location and there was another location 2 miles from where I was staying.
# offer recommended:
# Result: Voucher
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: You need more staff to accommodate travelers who are in a hurry. Specifically, cut down the wait time to either retrieve or turn in a rental car.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: The only unpleasant aspects of interacting with personnel from the company was having to wait in a long line since most windows were closed. Also, they tried really hard to sell additional insurance coverage which was obnoxious.
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: they were a little slow
# offer recommended:
# Result: Free Upgrade
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Please back to lower the prices.
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Please lower the prices.
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Slow, long lineup
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: They should upgrade me every time.
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Most windows were closed.
# offer recommended:
# Result: Free Upgrade
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: car cost more because I didn't pay when I reserved it
# offer recommended:
# Result: Voucher
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Please stop increasing the prices.
# offer recommended:
# Result: Free Upgrade
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: They had problem to find reservation number, so whole process took too long time.
# offer recommended:
# Result: On-demand pickup location
# Expected: Voucher
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Customer service is horrible. I reserved through on-line which did not indicate/state I had to provide proof of insurance during pickup. The manager denied the reservation and after long and rude argument he finally gave in.
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: I haven't actually spoken with anyone from a car rental organization for quite a while.  When I did (probably about three years ago), I believe they were polite enough. However, I always hate to wait in lines when we have a lot of luggage.
# offer recommended:
# Result: On-demand pickup location
# Expected: Free Upgrade
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended:
# Result: Premium features
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: They forgot to ask for my driver's license.
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: For the most part, they it's been really good service.  I usually rent from the airports because it's much cheaper.  Once they charged me over and I had to hunt down the accounting department to get my money back.  it was a pain.
# offer recommended:
# Result: Voucher
# Expected: Voucher
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: The people where generally good, but overworked.  The printer went down.  The poor woman working the register was about to pull her hair out.  Customers were yelling at her, not me, but she was not in charge of the issues.
# offer recommended:
# Result: Voucher
# Expected: On-demand pickup location
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: The person who assisted me was not very friendly and didn't like to give the details I was asking for (gas refill packages, insurance, etc.).
# offer recommended:
# Result: Voucher
# Expected: Premium features
#
#
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: It took us almost three hours just to get a car! It was absurd.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location
#  Generate next best offer to unsatisfied customer. Choose offer recommendation from the following: 'On-demand pickup location', 'Free Upgrade', 'Voucher', 'Premium features'.
#
# comment: last time I rented a car was at Manchester, NH airport and they do not have office there anymore
# offer recommended: On-demand pickup location
#
# comment: Please lower the prices.
# offer recommended: Free Upgrade
#
# comment: Customer is important for the enjoyment of the car.  If it's a bad experience we won't return to that company if we can avoid it - they should remember abotut this
# offer recommended: Voucher
#
# comment: Agents usually try to get you to take insurance and pay for full tank of gas.  Some persist even after a "no thanks."  Even after noting preferences on my frequent user file that says I don't want them.
# offer recommended: Premium features
#
# comment: the rep was friendly but it was so loud in there that I could not hear what she was saying. I HATE having to walk across a big lot with all of my bags in search of my car which is always in the furthest corner.
# offer recommended:
# Result: On-demand pickup location
# Expected: On-demand pickup location

# %% [markdown]
# ### Calculate the F1 micro score

# %%
from sklearn.metrics import f1_score

# print(offer_recommended)
# print(results)
print('f1_micro_score', f1_score(offer_recommended, results, average='micro'))
# Out:
# f1_micro_score 0.5084745762711864

# %% [markdown]
# ---

# %% [markdown]
# Copyright © 2023 IBM. This notebook and its source code are released under the terms of the MIT License.
